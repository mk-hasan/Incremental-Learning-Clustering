# %%
#plotting-train from scratch

# %%
cifar10_baseline = [0.9110000014305115, 0.9450000047683715, 0.752999997138977, 0.6899999976158142, 0.864000004529953, 0.8060000002384186, 0.9200000047683716, 0.8909999966621399, 0.935999995470047, 0.8819999933242798]

# %%
acc_gc = [0.5189999997615814, 0.6429999887943267, 0.5289999961853027, 0.3640000015497208, 0.7810000002384185, 0.6809999942779541, 0.44599999487400055, 0.30700000524520876, 0.4]

# %%
acc_gc_ref = [0.6219999969005585, 0.5509999871253968, 0.5009999930858612, 0.3909999966621399, 0.6780000030994415, 0.688999992609024, 0.510999995470047, 0.45499999523162843]

# %%
ap = [1,0.69,0.58,0.34,0.60,0.54,0.58,0.80,0.72,0.69]
at = [0.69,1,0.60,0.35,0.63,0.37,0.60,0.72,0.92,0.84]
bi = [0.58,0.60,1,0.75,0.82,0.86,0.81,0.60,0.63,0.86]
deer= [0.34,0.35,0.75,1,0.77,0.71,0.81,0.35,0.37,0.77]
dog = [0.60,0.63,0.82,0.77,1,0.74,0.77,0.63,0.66,0.86]
frog = [0.54,0.57,0.86,0.71,0.74,1,0.71,0.57,0.60,0.74]
horse = [0.58,0.60,0.81,0.81,0.77,0.71,1,0.60,0.63,0.63]
ship=[0.80,0.72,0.60,0.35,0.63,0.57,0.60,1,0.75,0.72]
truk = [0.72,0.92,0.63,0.37,0.66,0.60,0.63,0.75,1,0.84]
cat= [0.69,0.84,0.86,0.77,0.86,0.74,0.63,0.72,0.84,1]

# %%
all_sm=[]
all_sm.append(ap)
all_sm.append(at)
all_sm.append(bi)
all_sm.append(deer)
all_sm.append(dog)
all_sm.append(frog)
all_sm.append(horse)
all_sm.append(ship)
all_sm.append(truk)
all_sm.append(cat)

# %%
labels1 = ["airplane",'automobile','bird','cat','deer','dog','frog','horse','ship','truck']

# %%
import numpy as np; np.random.seed(0)
import seaborn as sns; sns.set()
from matplotlib import pyplot as plt
plt.figure(figsize=(15,12))
ax = sns.heatmap(all_sm,annot=True,linewidths=.5,cmap="YlGnBu")
ax.set_xticklabels(labels1)
ax.set_yticklabels(labels1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a102fefff767> in <module>
#       3 from matplotlib import pyplot as plt
#       4 plt.figure(figsize=(15,12))
# ----> 5 ax = sns.heatmap(all_sm,annot=True,linewidths=.5,cmap="YlGnBu")
#       6 ax.set_xticklabels(labels1)
#       7 ax.set_yticklabels(labels1)
#
# NameError: name 'all_sm' is not defined

# %%
ap = [1,0.86,0.83,0.81,0.83,0.66,0.95,0.66,0.60,0.70]
at = [0.86,1,0.86,0.65,0.87,0.70,0.90,0.70,0.63,0.73]
bi = [0.83,0.86,1,0.81,0.83,0.66,0.86,0.67,0.60,0.70]
deer= [0.81,0.85,0.81,1,0.89,0.73,0.89,0.73,0.66,0.77]
dog = [0.83,0.87,0.83,0.89,1,0.77,0.86,0.77,0.70,0.82]
frog = [0.66,0.70,0.66,0.73,0.77,1,0.70,0.90,0.63,0.84]
horse = [0.95,0.90,0.86,0.89,0.86,0.70,1,0.70,0.63,0.73]
ship=[0.66,0.70,0.67,0.73,0.77,0.90,0.70,1,0.66,0.84]
truk = [0.60,0.63,0.60,0.66,0.70,0.63,0.63,0.66,1,0.66]
cat= [0.70,0.73,0.70,0.77,0.82,0.84,0.73,0.84,0.66,1]

# %%
all_sm=[]
all_sm.append(ap)
all_sm.append(at)
all_sm.append(bi)
all_sm.append(deer)
all_sm.append(dog)
all_sm.append(frog)
all_sm.append(horse)
all_sm.append(ship)
all_sm.append(truk)
all_sm.append(cat)

# %%
labels1 = ["T-shirt",'Trouser','Pullover','Dress','Coat','Sandal','Shirt','Sneaker','Bag','Boot']

# %%
import numpy as np; np.random.seed(0)
import seaborn as sns; sns.set()
from matplotlib import pyplot as plt
plt.figure(figsize=(15,12))
ax = sns.heatmap(all_sm,annot=True,linewidths=.5,cmap="YlGnBu")
ax.set_xticklabels(labels1)
ax.set_yticklabels(labels1)
plt.show()

# %%
#Cifar-10 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
baseline = [[0.8920000195503235, 0.9829999804496765, 0.859000027179718, 0.9210000038146973, 0.8840000033378601, 0.9419999718666077, 0.7450000047683716, 0.6919999718666077, 0.984000027179718]]
ref = [0.4689999967813492, 0.4879999965429306, 0.5400000065565109, 0.1979999989271164, 0.5410000026226044, 0.435999995470047, 0.5559999883174896, 0.41399999856948855, 0.35600000619888306]
nr = [0.5669999957084656, 0.7299999952316284, 0.30600000321865084, 0.23700000196695328, 0.4869999885559082, 0.4849999964237213, 0.786000007390976, 0.3780000001192093, 0.6310000061988831]
flist = []
flist.append(baseline)
flist.append(ref)
flist.append(nr)

# %%
baseline = [0.8809999823570251, 0.75, 0.9179999828338623, 0.9860000014305115, 0.8960000276565552, 0.8970000147819519, 0.6909999847412109, 0.9330000281333923, 0.984000027179718]
ref = [0.44,0.08,0.19,0.97,0.21,0.69,0.90,0.65,0.70]
nr = [0.76,0.09,0.68,0.89,0.78,0.44,0.83,0.76,0.91]
flist = []
flist.append(baseline)
flist.append(ref)
flist.append(nr)

# %%
df = pd.DataFrame(flist,columns=['1', '2', '3', '4', '5','6','7','8','9'])

# %%
df.plot()

# %%
full_target_class_ids = [1, 7, 4, 2, 5, 3, 8, 6, 9]
class_names= class_names = ['others','Tshirt', 'Trouser', 'PullOver', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'AnkelBoat']

# %%
    plt.plot(np.arange(9), nr, label='Growing Classifer', marker='^')
    plt.plot(np.arange(9), ref, label='Growing Classifer (Refining)', marker='^')
    plt.plot(np.arange(9), baseline, label='Train from scratch', marker='^')
    plt.legend()
    plt.xlabel('class ID ' + str([class_names[el] for el in full_target_class_ids]))
    plt.ylabel('accuracy')
    plt.title('GC (with and without refining) v.s. Train from scratch')
    plt.show()
